# %%
import pandas as pd

# %%
df = pd.read_csv("../stance_code/Evaluation/bert_dummy_output/non_reverse_bert_cons_epoch5_raw_score.csv")

# %%
df
# Out:
#       undermine_score  support_score  predict_label  gold
# 0           -3.298447       3.252912              1     1
# 1            3.847457      -3.262123              0     0
# 2           -3.267502       3.174200              1     1
# 3           -3.226553       3.147269              1     1
# 4           -3.088458       2.970518              1     1
# ...               ...            ...            ...   ...
# 2768         2.061727      -1.558688              0     0
# 2769         1.699087      -1.463090              0     0
# 2770        -1.879320       1.803434              1     1
# 2771         2.407053      -1.869287              0     1
# 2772        -3.018865       2.861231              1     1
#
# [2773 rows x 4 columns]

# %%
df_ori = pd.read_csv("../stance_code/Dataset/test.tsv", delimiter="\t")

# %%
df_ori
# Out:
#       Label  x  y                                              claim  \
# 0         1  0  0                      School Day Should Be Extended
# 1         0  0  0                      School Day Should Be Extended
# 2         1  0  0                      School Day Should Be Extended
# 3         1  0  0                      School Day Should Be Extended
# 4         1  0  0                      School Day Should Be Extended
# ...     ... .. ..                                                ...
# 2768      0  0  0  Illegal downloaders should be cut off from the...
# 2769      0  0  0  Illegal downloaders should be cut off from the...
# 2770      1  0  0  Illegal downloaders should be cut off from the...
# 2771      1  0  0  Illegal downloaders should be cut off from the...
# 2772      1  0  0  Illegal downloaders should be cut off from the...
#
#                                             perspective
# 0                       Lessons would feel less broken.
# ...

# %%
df_concat = pd.concat([df_ori,df],axis=1)

# %%
df_concat
# Out:
#       Label  x  y                                              claim  \
# 0         1  0  0                      School Day Should Be Extended
# 1         0  0  0                      School Day Should Be Extended
# 2         1  0  0                      School Day Should Be Extended
# 3         1  0  0                      School Day Should Be Extended
# 4         1  0  0                      School Day Should Be Extended
# ...     ... .. ..                                                ...
# 2768      0  0  0  Illegal downloaders should be cut off from the...
# 2769      0  0  0  Illegal downloaders should be cut off from the...
# 2770      1  0  0  Illegal downloaders should be cut off from the...
# 2771      1  0  0  Illegal downloaders should be cut off from the...
# 2772      1  0  0  Illegal downloaders should be cut off from the...
#
#                                             perspective  undermine_score  \
# ...

# %%
df_concat[df_concat.gold==0][df_concat.predict_label==0]
# Out:
# C:\Users\arsen\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Label  x  y                                              claim  \
# 1         0  0  0                      School Day Should Be Extended
# 13        0  0  0                 Raise The School Leaving Age To 18
# 14        0  0  0                 Raise The School Leaving Age To 18
# 15        0  0  0                 Raise The School Leaving Age To 18
# 16        0  0  0                 Raise The School Leaving Age To 18
# ...     ... .. ..                                                ...
# 2761      0  0  0  Illegal downloaders should be cut off from the...
# 2763      0  0  0  Illegal downloaders should be cut off from the...
# 2766      0  0  0  Illegal downloaders should be cut off from the...
# 2768      0  0  0  Illegal downloaders should be cut off from the...
# ...

# %%
df_concat[df_concat.gold==0][df_concat.predict_label==1]
# Out:
# C:\Users\arsen\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Label  x  y                                              claim  \
# 48        0  0  0                    Make all museums free of charge
# 65        0  0  0                      Chess must be at the Olympics
# 75        0  0  0  ‘The Spear’ should have remained on public dis...
# 82        0  0  0     Federal States are better than unitary nations
# 113       0  0  0                      College education is worth it
# ...     ... .. ..                                                ...
# 2760      0  0  0  Illegal downloaders should be cut off from the...
# 2762      0  0  0  Illegal downloaders should be cut off from the...
# 2764      0  0  0  Illegal downloaders should be cut off from the...
# 2765      0  0  0  Illegal downloaders should be cut off from the...
# ...

# %%
(df_concat[df_concat.gold==0][df_concat.predict_label==1])[0:100].to_excel("./stancy_opp/stancy_failed_100_gold0.xlsx")
# Out:
# C:\Users\arsen\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
(df_concat[df_concat.gold==0][df_concat.predict_label==0])[0:100].to_excel("./stancy_opp/stancy_succeeded_100_gold0.xlsx")
# Out:
# C:\Users\arsen\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df_concat[df_concat.gold==1][df_concat.predict_label==1]
# Out:
# C:\Users\arsen\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Label  x  y                                              claim  \
# 0         1  0  0                      School Day Should Be Extended
# 2         1  0  0                      School Day Should Be Extended
# 3         1  0  0                      School Day Should Be Extended
# 4         1  0  0                      School Day Should Be Extended
# 5         1  0  0                 Raise The School Leaving Age To 18
# ...     ... .. ..                                                ...
# 2745      1  0  0  Illegal downloaders should be cut off from the...
# 2746      1  0  0  Illegal downloaders should be cut off from the...
# 2754      1  0  0  Illegal downloaders should be cut off from the...
# 2770      1  0  0  Illegal downloaders should be cut off from the...
# ...

# %%
df_concat[df_concat.gold==1][df_concat.predict_label==0]
# Out:
# C:\Users\arsen\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Label  x  y                                              claim  \
# 61        1  0  0                      Chess must be at the Olympics
# 80        1  0  0     Federal States are better than unitary nations
# 84        1  0  0                   The Catholic Church needs reform
# 85        1  0  0                   The Catholic Church needs reform
# 86        1  0  0                   The Catholic Church needs reform
# ...     ... .. ..                                                ...
# 2756      1  0  0  Illegal downloaders should be cut off from the...
# 2757      1  0  0  Illegal downloaders should be cut off from the...
# 2758      1  0  0  Illegal downloaders should be cut off from the...
# 2759      1  0  0  Illegal downloaders should be cut off from the...
# ...

# %%
df_100gold0_failed = pd.read_excel("../stance_code/Dataset/manul_opposite/stancy_100_gold0/stancy_failed_100_gold0.xlsx")

# %%
df_100gold0_failed.to_csv("../stance_code/Dataset/manul_opposite/stancy_100_gold0/failed/test.tsv",  sep="\t")

# %%
df_100gold0_succeeded = pd.read_excel("../stance_code/Dataset/manul_opposite/stancy_100_gold0/stancy_succeeded_100_gold0.xlsx")

# %%
df_100gold0_succeeded.to_csv("../stance_code/Dataset/manul_opposite/stancy_100_gold0/succeeded/test.tsv",  sep="\t")
