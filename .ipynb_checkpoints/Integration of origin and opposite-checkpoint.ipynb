# %%
import pandas as pd

# %%
df_oppsite=pd.read_csv("D:/Jupyter/stance_code_local/failed_samples/500/test.tsv",sep="\t", header=None, index_col=False)
new_score= pd.read_csv('D:/Jupyter/stance_code_local/evaluation/bert_local_output/500/opposite_raw_score.csv')
df_small= pd.read_excel('D:/Jupyter/stance_code_local/failed_samples/500_opposite_gold_0.xlsx', index_col=0)

# %%
df_oppsite
# Out:
#      0  1  2                                           3  \
# 0    0  0  0               School Day Should Be Extended
# 1    0  0  0          Raise The School Leaving Age To 18
# 2    0  0  0          Raise The School Leaving Age To 18
# 3    0  0  0          Raise The School Leaving Age To 18
# 4    0  0  0          Raise The School Leaving Age To 18
# ..  .. .. ..                                         ...
# 495  0  0  0  We should drop the sanctions against Cuba.
# 496  0  0  0  We should drop the sanctions against Cuba.
# 497  0  0  0  We should drop the sanctions against Cuba.
# 498  0  0  0  We should drop the sanctions against Cuba.
# 499  0  0  0  We should drop the sanctions against Cuba.
#
#                                                      4         5         6
# 0                                      Enough funding… -0.936400  1.087037
# 1       Big is accomplished when education is forced.  -1.803217  2.411567
# 2                        Forced education achieves big -0.770338  0.916249
# 3    All skills are best learnt in a classroom envi... -1.569882  2.049508
# 4    None skills are worse learned inside the class... -0.913012  1.131848
# ..                                                 ...       ...       ...
# 495  Ending the embargo before the Cuban government... -1.201278  1.535978
# 496  Cuba should not be subject to sanctions becaus... -1.753255  2.372272
# 497  Cuba is known to fight terrorism so sanctions ... -1.555489  2.083695
# 498  Because Cuba fights terrorism, it should not h... -1.627042  2.139139
# 499  The United States is not able to target the Cu... -1.390711  1.846242
#
# [500 rows x 7 columns]

# %%
df_small.rename(columns={'undermine_score':'undermine_origin','support_score':'support_origin', 'predict_label':'predict_origin', 'gold_label':'gold_origin'},inplace=True)

# %%
new_score.rename(columns={'undermine_score':'undermine_opposite','support_score':'support_opposite', 'predict_label':'predict_opposite', 'gold':'gold_opposite' },inplace=True)

# %%
integration = pd.concat([df_small.reset_index(drop=True), new_score], axis = 1)

# %%
integration
# Out:
#                                          claims  \
# 0                 School Day Should Be Extended
# 1            Raise The School Leaving Age To 18
# 2            Raise The School Leaving Age To 18
# 3            Raise The School Leaving Age To 18
# 4            Raise The School Leaving Age To 18
# ..                                          ...
# 495  We should drop the sanctions against Cuba.
# 496  We should drop the sanctions against Cuba.
# 497  We should drop the sanctions against Cuba.
# 498  We should drop the sanctions against Cuba.
# 499  We should drop the sanctions against Cuba.
#
#                                            perpectives  \
# 0                                  Not enough funding…
# 1     Little is accomplished when education is forced.
# 2                     Forced Education Achieves Little
# 3    Not all skills are best learnt in a classroom ...
# 4    Some skills are better learned outside the cla...
# ..                                                 ...
# 495  Ending the embargo before the Cuban government...
# 496  Cuba should be subject to sanctions because it...
# 497  Cuba is knows to sponsor terrorism so sanction...
# 498  Because Cuba supports terrorism, it should hav...
# 499  The United States is able to target the Cuban ...
#
#                                               opposite  undermine_origin  \
# 0                                      Enough funding…         -0.936400
# 1       Big is accomplished when education is forced.          -1.803217
# 2                        Forced education achieves big         -0.770338
# 3    All skills are best learnt in a classroom envi...         -1.569882
# 4    None skills are worse learned inside the class...         -0.913012
# ..                                                 ...               ...
# 495  Ending the embargo before the Cuban government...         -1.201278
# 496  Cuba should not be subject to sanctions becaus...         -1.753255
# 497  Cuba is known to fight terrorism so sanctions ...         -1.555489
# 498  Because Cuba fights terrorism, it should not h...         -1.627042
# 499  The United States is not able to target the Cu...         -1.390712
#
#      support_origin  predict_origin  gold_origin  undermine_opposite  \
# 0          1.087037               1            0           -3.311615
# 1          2.411567               1            0           -2.613755
# 2          0.916249               1            0           -2.250728
# 3          2.049508               1            0            1.656653
# 4          1.131848               1            0            2.235727
# ..              ...             ...          ...                 ...
# 495        1.535978               1            0            1.709028
# 496        2.372272               1            0            1.225708
# 497        2.083695               1            0            0.949165
# 498        2.139139               1            0           -0.931023
# 499        1.846242               1            0                 NaN
#
#      support_opposite  predict_opposite  gold_opposite
# 0            2.915638               1.0            0.0
# 1            2.084154               1.0            0.0
# 2            1.649728               1.0            0.0
# 3           -1.931105               0.0            0.0
# 4           -2.230491               0.0            0.0
# ..                ...               ...            ...
# 495         -1.735075               0.0            0.0
# 496         -1.335899               0.0            0.0
# 497         -1.014262               0.0            0.0
# 498          0.659661               1.0            0.0
# 499               NaN               NaN            NaN
#
# [500 rows x 11 columns]

# %%
integration["oppose_sum"]=integration.undermine_origin+integration.support_opposite
integration["support_sum"]=integration.support_origin+integration.undermine_opposite

# %%
# integration.drop('predict_label',axis=1,inplace=True)

# %%
integration.loc[integration['oppose_sum']==integration['support_sum'], 'final_label'] = '0'
integration.loc[integration['oppose_sum']>integration['support_sum'], 'final_label'] = '0'
integration.loc[integration['oppose_sum']<integration['support_sum'], 'final_label'] = '1'

# %%
integration
# Out:
#                                          claims  \
# 0                 School Day Should Be Extended
# 1            Raise The School Leaving Age To 18
# 2            Raise The School Leaving Age To 18
# 3            Raise The School Leaving Age To 18
# 4            Raise The School Leaving Age To 18
# ..                                          ...
# 495  We should drop the sanctions against Cuba.
# 496  We should drop the sanctions against Cuba.
# 497  We should drop the sanctions against Cuba.
# 498  We should drop the sanctions against Cuba.
# 499  We should drop the sanctions against Cuba.
#
#                                            perpectives  \
# 0                                  Not enough funding…
# 1     Little is accomplished when education is forced.
# 2                     Forced Education Achieves Little
# 3    Not all skills are best learnt in a classroom ...
# 4    Some skills are better learned outside the cla...
# ..                                                 ...
# 495  Ending the embargo before the Cuban government...
# 496  Cuba should be subject to sanctions because it...
# 497  Cuba is knows to sponsor terrorism so sanction...
# 498  Because Cuba supports terrorism, it should hav...
# 499  The United States is able to target the Cuban ...
#
#                                               opposite  undermine_origin  \
# 0                                      Enough funding…         -0.936400
# 1       Big is accomplished when education is forced.          -1.803217
# 2                        Forced education achieves big         -0.770338
# 3    All skills are best learnt in a classroom envi...         -1.569882
# 4    None skills are worse learned inside the class...         -0.913012
# ..                                                 ...               ...
# 495  Ending the embargo before the Cuban government...         -1.201278
# 496  Cuba should not be subject to sanctions becaus...         -1.753255
# 497  Cuba is known to fight terrorism so sanctions ...         -1.555489
# 498  Because Cuba fights terrorism, it should not h...         -1.627042
# 499  The United States is not able to target the Cu...         -1.390712
#
#      support_origin  predict_origin  gold_origin  undermine_opposite  \
# 0          1.087037               1            0           -3.311615
# 1          2.411567               1            0           -2.613755
# 2          0.916249               1            0           -2.250728
# 3          2.049508               1            0            1.656653
# 4          1.131848               1            0            2.235727
# ..              ...             ...          ...                 ...
# 495        1.535978               1            0            1.709028
# 496        2.372272               1            0            1.225708
# 497        2.083695               1            0            0.949165
# 498        2.139139               1            0           -0.931023
# 499        1.846242               1            0                 NaN
#
#      support_opposite  predict_opposite  gold_opposite  oppose_sum  \
# 0            2.915638               1.0            0.0    1.979238
# 1            2.084154               1.0            0.0    0.280936
# 2            1.649728               1.0            0.0    0.879390
# 3           -1.931105               0.0            0.0   -3.500987
# 4           -2.230491               0.0            0.0   -3.143503
# ..                ...               ...            ...         ...
# 495         -1.735075               0.0            0.0   -2.936353
# 496         -1.335899               0.0            0.0   -3.089154
# 497         -1.014262               0.0            0.0   -2.569751
# 498          0.659661               1.0            0.0   -0.967381
# 499               NaN               NaN            NaN         NaN
#
#      support_sum final_label
# 0      -2.224578           0
# 1      -0.202189           0
# 2      -1.334479           0
# 3       3.706161           1
# 4       3.367576           1
# ..           ...         ...
# 495     3.245006           1
# 496     3.597980           1
# 497     3.032861           1
# 498     1.208116           1
# 499          NaN         NaN
#
# [500 rows x 14 columns]

# %%
# integration.to_excel('D:/Jupyter/stance_code_local/evaluation/opposite_evaluation/opposite_experiment.xlsx')
integration.to_csv('D:/Jupyter/stance_code_local/evaluation/opposite_evaluation/500/opposite_experiment.csv')
