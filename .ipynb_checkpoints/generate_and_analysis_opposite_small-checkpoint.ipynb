# %%
import pandas as pd

# %%
df_format=pd.read_csv('D:/Jupyter/stance_code/Dataset/test.tsv',sep ="\t", header=None)
df_small= pd.read_excel('D:/Jupyter/stance_code_local/failed_samples/500_opposite_gold_0.xlsx')

# %%
df_format

# %%
df_small
# Out:
#      Unnamed: 0                                      claims  \
# 0             0               School Day Should Be Extended
# 1            14          Raise The School Leaving Age To 18
# 2            16          Raise The School Leaving Age To 18
# 3            17          Raise The School Leaving Age To 18
# 4            18          Raise The School Leaving Age To 18
# ..          ...                                         ...
# 495        2323  We should drop the sanctions against Cuba.
# 496        2326  We should drop the sanctions against Cuba.
# 497        2327  We should drop the sanctions against Cuba.
# 498        2328  We should drop the sanctions against Cuba.
# 499        2329  We should drop the sanctions against Cuba.
#
#                                            perpectives  \
# 0                                  Not enough funding…
# 1     Little is accomplished when education is forced.
# 2                     Forced Education Achieves Little
# 3    Not all skills are best learnt in a classroom ...
# 4    Some skills are better learned outside the cla...
# ..                                                 ...
# 495  Ending the embargo before the Cuban government...
# 496  Cuba should be subject to sanctions because it...
# 497  Cuba is knows to sponsor terrorism so sanction...
# 498  Because Cuba supports terrorism, it should hav...
# 499  The United States is able to target the Cuban ...
#
#                                               opposite  undermine_score  \
# 0                                      Enough funding…        -0.936400
# 1       Big is accomplished when education is forced.         -1.803217
# 2                        Forced education achieves big        -0.770338
# 3    All skills are best learnt in a classroom envi...        -1.569882
# 4    None skills are worse learned inside the class...        -0.913012
# ..                                                 ...              ...
# 495  Ending the embargo before the Cuban government...        -1.201278
# 496  Cuba should not be subject to sanctions becaus...        -1.753255
# 497  Cuba is known to fight terrorism so sanctions ...        -1.555489
# 498  Because Cuba fights terrorism, it should not h...        -1.627042
# 499  The United States is not able to target the Cu...        -1.390712
#
#      support_score  predict_label  gold_label
# 0         1.087037              1           0
# 1         2.411567              1           0
# 2         0.916249              1           0
# 3         2.049508              1           0
# 4         1.131848              1           0
# ..             ...            ...         ...
# 495       1.535978              1           0
# 496       2.372272              1           0
# 497       2.083695              1           0
# 498       2.139139              1           0
# 499       1.846242              1           0
#
# [500 rows x 8 columns]

# %%
df_new = pd.concat([df_format.iloc[0:500],df_small],axis=1)

# %%
df_new
# Out:
#      0  1  2                                           3  \
# 0    1  0  0               School Day Should Be Extended
# 1    0  0  0               School Day Should Be Extended
# 2    1  0  0               School Day Should Be Extended
# 3    1  0  0               School Day Should Be Extended
# 4    1  0  0               School Day Should Be Extended
# ..  .. .. ..                                         ...
# 495  0  0  0  Encourage fewer people to go to university
# 496  0  0  0  Encourage fewer people to go to university
# 497  1  0  0  Encourage fewer people to go to university
# 498  0  0  0  Encourage fewer people to go to university
# 499  0  0  0  Encourage fewer people to go to university
#
#                                                      4  Unnamed: 0  \
# 0                      Lessons would feel less broken.           0
# 1                                 Not enough fundng...          14
# 2                          So much easier for parents!          16
# 3                              Less need for homework.          17
# 4                            Time to finish activities          18
# ..                                                 ...         ...
# 495              We must retain a respect for academia        2323
# 496  University education gives people something to...        2326
# 497  Universities don’t have unlimited places avail...        2327
# 498  College graduates are more productive as membe...        2328
# 499  An increase of graduates from college is benef...        2329
#
#                                          claims  \
# 0                 School Day Should Be Extended
# 1            Raise The School Leaving Age To 18
# 2            Raise The School Leaving Age To 18
# 3            Raise The School Leaving Age To 18
# 4            Raise The School Leaving Age To 18
# ..                                          ...
# 495  We should drop the sanctions against Cuba.
# 496  We should drop the sanctions against Cuba.
# 497  We should drop the sanctions against Cuba.
# 498  We should drop the sanctions against Cuba.
# 499  We should drop the sanctions against Cuba.
#
#                                            perpectives  \
# 0                                  Not enough funding…
# 1     Little is accomplished when education is forced.
# 2                     Forced Education Achieves Little
# 3    Not all skills are best learnt in a classroom ...
# 4    Some skills are better learned outside the cla...
# ..                                                 ...
# 495  Ending the embargo before the Cuban government...
# 496  Cuba should be subject to sanctions because it...
# 497  Cuba is knows to sponsor terrorism so sanction...
# 498  Because Cuba supports terrorism, it should hav...
# 499  The United States is able to target the Cuban ...
#
#                                               opposite  undermine_score  \
# 0                                      Enough funding…        -0.936400
# 1       Big is accomplished when education is forced.         -1.803217
# 2                        Forced education achieves big        -0.770338
# 3    All skills are best learnt in a classroom envi...        -1.569882
# 4    None skills are worse learned inside the class...        -0.913012
# ..                                                 ...              ...
# 495  Ending the embargo before the Cuban government...        -1.201278
# 496  Cuba should not be subject to sanctions becaus...        -1.753255
# 497  Cuba is known to fight terrorism so sanctions ...        -1.555489
# 498  Because Cuba fights terrorism, it should not h...        -1.627042
# 499  The United States is not able to target the Cu...        -1.390712
#
#      support_score  predict_label  gold_label
# 0         1.087037              1           0
# 1         2.411567              1           0
# 2         0.916249              1           0
# 3         2.049508              1           0
# 4         1.131848              1           0
# ..             ...            ...         ...
# 495       1.535978              1           0
# 496       2.372272              1           0
# 497       2.083695              1           0
# 498       2.139139              1           0
# 499       1.846242              1           0
#
# [500 rows x 13 columns]

# %%
col = ["0","1","2", "claims", "opposite", "undermine_score", "support_score"]
final_df = pd.DataFrame(df_new,columns=col)
final_df = final_df.fillna("0")

# %%
final_df

# %%
final_df.to_csv("D:/Jupyter/stance_code_local/failed_samples/500/test.tsv",sep="\t",header = None, index=False)

# %%
#after bert prediction

# %%
eval_df = pd.read_csv('D:/Jupyter/stance_code_local/evaluation/bert_local_output/opposite_raw_score.csv')

# %%
eval_df
# Out:
#     undermine_score  support_score  predict_label  gold
# 0         -3.311615       2.915638              1     0
# 1         -2.613755       2.084154              1     0
# 2         -2.250728       1.649728              1     0
# 3          1.656653      -1.931105              0     0
# 4          2.235727      -2.230491              0     0
# ..              ...            ...            ...   ...
# 93         2.344531      -2.364122              0     0
# 94        -0.588766       0.434656              1     0
# 95        -1.058739       0.811802              1     0
# 96        -1.625625       1.306795              1     0
# 97        -0.875861       0.690869              1     0
#
# [98 rows x 4 columns]
