# %%
import pandas as pd

# %%
df_base_eval = pd.read_csv("../stance_code/Evaluation/bert_dummy_output/bert_base_bs32_lr2e_5_epoch4_raw_score.csv")

# %%
df_base_eval
# Out:
#       undermine_score  support_score  predict_label  gold
# 0           -3.120266       3.146689              1     1
# 1           -1.417848       1.625434              1     0
# 2           -2.544775       2.716588              1     1
# 3            0.655416      -0.446708              0     1
# 4            0.865310      -0.591936              0     1
# ...               ...            ...            ...   ...
# 2768        -3.130517       2.797219              1     0
# 2769         0.344362      -0.042596              0     0
# 2770         1.233127      -1.583184              0     1
# 2771         2.553239      -2.488668              0     1
# 2772         0.110734      -0.186051              0     1
#
# [2773 rows x 4 columns]

# %%
df_ori = pd.read_csv("../stance_code/Dataset/test.tsv", delimiter="\t")

# %%
df_ori
# Out:
#       Label  x  y                                              claim  \
# 0         1  0  0                      School Day Should Be Extended
# 1         0  0  0                      School Day Should Be Extended
# 2         1  0  0                      School Day Should Be Extended
# 3         1  0  0                      School Day Should Be Extended
# 4         1  0  0                      School Day Should Be Extended
# ...     ... .. ..                                                ...
# 2768      0  0  0  Illegal downloaders should be cut off from the...
# 2769      0  0  0  Illegal downloaders should be cut off from the...
# 2770      1  0  0  Illegal downloaders should be cut off from the...
# 2771      1  0  0  Illegal downloaders should be cut off from the...
# 2772      1  0  0  Illegal downloaders should be cut off from the...
#
#                                             perspective
# 0                       Lessons would feel less broken.
# 1                                  Not enough fundng...
# 2                           So much easier for parents!
# 3                               Less need for homework.
# 4                             Time to finish activities
# ...                                                 ...
# 2768  Cutting off internet capability is against hum...
# 2769                All humans deserve internet access.
# 2770  Internet access is a commodity not a human right.
# 2771       The internet is a utility not a human right.
# 2772  Just as electricity is not a human right, the ...
#
# [2773 rows x 5 columns]

# %%
df_com = pd.concat([df_ori, df_base_eval],axis=1)

# %%
df_com
# Out:
#       Label  x  y                                              claim  \
# 0         1  0  0                      School Day Should Be Extended
# 1         0  0  0                      School Day Should Be Extended
# 2         1  0  0                      School Day Should Be Extended
# 3         1  0  0                      School Day Should Be Extended
# 4         1  0  0                      School Day Should Be Extended
# ...     ... .. ..                                                ...
# 2768      0  0  0  Illegal downloaders should be cut off from the...
# 2769      0  0  0  Illegal downloaders should be cut off from the...
# 2770      1  0  0  Illegal downloaders should be cut off from the...
# 2771      1  0  0  Illegal downloaders should be cut off from the...
# 2772      1  0  0  Illegal downloaders should be cut off from the...
#
#                                             perspective  undermine_score  \
# 0                       Lessons would feel less broken.        -3.120266
# 1                                  Not enough fundng...        -1.417848
# 2                           So much easier for parents!        -2.544775
# 3                               Less need for homework.         0.655416
# 4                             Time to finish activities         0.865310
# ...                                                 ...              ...
# 2768  Cutting off internet capability is against hum...        -3.130517
# 2769                All humans deserve internet access.         0.344362
# 2770  Internet access is a commodity not a human right.         1.233127
# 2771       The internet is a utility not a human right.         2.553239
# 2772  Just as electricity is not a human right, the ...         0.110734
#
#       support_score  predict_label  gold
# 0          3.146689              1     1
# 1          1.625434              1     0
# 2          2.716588              1     1
# 3         -0.446708              0     1
# 4         -0.591936              0     1
# ...             ...            ...   ...
# 2768       2.797219              1     0
# 2769      -0.042596              0     0
# 2770      -1.583184              0     1
# 2771      -2.488668              0     1
# 2772      -0.186051              0     1
#
# [2773 rows x 9 columns]

# %%
(df_com[df_com.gold==0][df_com.predict_label==1])
# Out:
# C:\Users\arsen\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Label  x  y                                              claim  \
# 1         0  0  0                      School Day Should Be Extended
# 17        0  0  0                 Raise The School Leaving Age To 18
# 48        0  0  0                    Make all museums free of charge
# 63        0  0  0                      Chess must be at the Olympics
# 75        0  0  0  ‘The Spear’ should have remained on public dis...
# ...     ... .. ..                                                ...
# 2760      0  0  0  Illegal downloaders should be cut off from the...
# 2761      0  0  0  Illegal downloaders should be cut off from the...
# 2763      0  0  0  Illegal downloaders should be cut off from the...
# 2765      0  0  0  Illegal downloaders should be cut off from the...
# 2768      0  0  0  Illegal downloaders should be cut off from the...
#
#                                             perspective  undermine_score  \
# 1                                  Not enough fundng...        -1.417848
# 17                     Forced Education Achieves Little        -0.765245
# 48               State funding should be used elsewhere        -2.082112
# 63    Opening up the Olympics for borderline sports ...        -0.116749
# 75                                       Public Decency        -0.184871
# ...                                                 ...              ...
# 2760                       Infringement of human rights        -1.097470
# 2761  The right to freedom and expression necessaril...        -1.438920
# 2763                 The internet should be open to all        -0.303672
# 2765  The right to internet access fills a gap in tr...        -0.699026
# 2768  Cutting off internet capability is against hum...        -3.130517
#
#       support_score  predict_label  gold
# 1          1.625434              1     0
# 17         0.709321              1     0
# 48         2.119118              1     0
# 63         0.081291              1     0
# 75         0.171482              1     0
# ...             ...            ...   ...
# 2760       1.211334              1     0
# 2761       1.333514              1     0
# 2763       0.843092              1     0
# 2765       0.871188              1     0
# 2768       2.797219              1     0
#
# [387 rows x 9 columns]

# %%
df_fail_0 = (df_com[df_com.gold==0][df_com.predict_label==1])
# Out:
# C:\Users\arsen\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df_fail_0.reset_index(drop=True)[0:99]
# Out:
#     Label  x  y                                              claim  \
# 0       0  0  0                      School Day Should Be Extended
# 1       0  0  0                 Raise The School Leaving Age To 18
# 2       0  0  0                    Make all museums free of charge
# 3       0  0  0                      Chess must be at the Olympics
# 4       0  0  0  ‘The Spear’ should have remained on public dis...
# ..    ... .. ..                                                ...
# 94      0  0  0    Christianity is the greatest deception of today
# 95      0  0  0    Christianity is the greatest deception of today
# 96      0  0  0    Christianity is the greatest deception of today
# 97      0  0  0  Force think tanks to reveal all of their sourc...
# 98      0  0  0  Force think tanks to reveal all of their sourc...
#
#                                           perspective  undermine_score  \
# 0                                Not enough fundng...        -1.417848
# 1                    Forced Education Achieves Little        -0.765245
# 2              State funding should be used elsewhere        -2.082112
# 3   Opening up the Olympics for borderline sports ...        -0.116749
# 4                                      Public Decency        -0.184871
# ..                                                ...              ...
# 94  It isn't christianity that's the deception, or...        -1.578203
# 95                         Christianity is not a lie!        -0.378610
# 96                     Christianity is not dishonest!        -1.885125
# 97          Private investors have a right to privacy        -1.817944
# 98           Privacy is a right to private investors.        -2.076119
#
#     support_score  predict_label  gold
# 0        1.625434              1     0
# 1        0.709321              1     0
# 2        2.119118              1     0
# 3        0.081291              1     0
# 4        0.171482              1     0
# ..            ...            ...   ...
# 94       1.493438              1     0
# 95       0.271428              1     0
# 96       1.851901              1     0
# 97       2.097475              1     0
# 98       2.151116              1     0
#
# [99 rows x 9 columns]

# %%
s500_gold_0 = pd.read_csv("../stance_code/Evaluation/antonym_output/antonym_pers_500_success_gold0_bert_base_bs32_lr2e_5_epoch4_raw_score.csv")

# %%
s500_gold_0.rename(columns={'undermine_score':'undermine_opposite','support_score':'support_opposite', 'predict_label':'predict_opposite', 'gold':'gold_opposite' },inplace=True)

# %%
s500_gold_0
# Out:
#      undermine_opposite  support_opposite  predict_opposite  gold_opposite
# 0              0.431604         -0.062047                 0              0
# 1             -0.292042          0.708196                 1              0
# 2              0.247453         -0.032293                 0              0
# 3             -1.238565          1.664096                 1              0
# 4              0.639184         -0.704727                 0              0
# ..                  ...               ...               ...            ...
# 495            2.794284         -1.857957                 0              0
# 496            2.037130         -1.585772                 0              0
# 497            0.438233          0.121602                 0              0
# 498           -1.536982          1.831256                 1              0
# 499            1.348785         -0.790271                 0              0
#
# [500 rows x 4 columns]

# %%
s250_gold_0 = pd.read_csv("success_samples/500_gold0/eval_100_gold0.csv")

# %%
s250_gold_0.rename(columns={'undermine_score':'undermine_origin','support_score':'support_origin', 'predict_label':'predict_origin', 'gold_label':'gold_origin'},inplace=True)

# %%
integration=pd.concat([s250_gold_0[0:100], s500_gold_0[250:350].reset_index(drop=True)],axis=1)

# %%
integration
# Out:
#                                    claims  \
# 0                         Golf is a Sport
# 1                         Golf is a Sport
# 2                         Golf is a Sport
# 3                         Golf is a Sport
# 4                         Golf is a Sport
# ..                                    ...
# 95  Voting should be compulsory in the UK
# 96  Voting should be compulsory in the UK
# 97  Voting should be compulsory in the UK
# 98  Voting should be compulsory in the UK
# 99  Voting should be compulsory in the UK
#
#                                           perpectives  undermine_origin  \
# 0   Experts believe golf does not require enough p...          0.156679
# 1   If you can compete in a professional tournamen...          1.020556
# 2   Golf does not have the physical rigors that sp...          0.732160
# 3   The fact that golf can be difficult and requir...          0.735514
# 4   That golf can be difficult and skills and prac...          1.448604
# ..                                                ...               ...
# 95  People can only make free choices if they want...          0.676437
# 96  What's the point of voting as politicians don'...          2.151275
# 97  Why should anyone bother to vote when politici...          1.043582
# 98  Once elected, politicians do what they want, s...          0.548052
# 99  Voting does not make sense as a rewardable/pun...          1.562263
#
#     support_origin  predict_origin  gold_origin  undermine_opposite  \
# 0        -0.169901               0            0           -0.638833
# 1        -0.970217               0            0           -2.578271
# 2        -0.680443               0            0           -1.148554
# 3        -0.665140               0            0           -1.294479
# 4        -1.401753               0            0           -1.019519
# ..             ...             ...          ...                 ...
# 95       -0.607702               0            0            2.059047
# 96       -2.150320               0            0            2.330699
# 97       -0.879661               0            0            2.007549
# 98       -0.475252               0            0            2.043130
# 99       -1.498444               0            0           -0.996068
#
#     support_opposite  predict_opposite  gold_opposite
# 0           0.565248                 1              0
# 1           2.718875                 1              0
# 2           1.108218                 1              0
# 3           1.191753                 1              0
# 4           0.849479                 1              0
# ..               ...               ...            ...
# 95         -1.623067                 0              0
# 96         -2.192789                 0              0
# 97         -1.668845                 0              0
# 98         -1.788328                 0              0
# 99          1.227736                 1              0
#
# [100 rows x 10 columns]

# %%
integration["oppose_sum"]=integration.undermine_origin-integration.undermine_opposite
integration["support_sum"]=integration.support_origin-integration.support_opposite

# %%
integration
# Out:
#                                    claims  \
# 0                         Golf is a Sport
# 1                         Golf is a Sport
# 2                         Golf is a Sport
# 3                         Golf is a Sport
# 4                         Golf is a Sport
# ..                                    ...
# 95  Voting should be compulsory in the UK
# 96  Voting should be compulsory in the UK
# 97  Voting should be compulsory in the UK
# 98  Voting should be compulsory in the UK
# 99  Voting should be compulsory in the UK
#
#                                           perpectives  undermine_origin  \
# 0   Experts believe golf does not require enough p...          0.156679
# 1   If you can compete in a professional tournamen...          1.020556
# 2   Golf does not have the physical rigors that sp...          0.732160
# 3   The fact that golf can be difficult and requir...          0.735514
# 4   That golf can be difficult and skills and prac...          1.448604
# ..                                                ...               ...
# 95  People can only make free choices if they want...          0.676437
# 96  What's the point of voting as politicians don'...          2.151275
# 97  Why should anyone bother to vote when politici...          1.043582
# 98  Once elected, politicians do what they want, s...          0.548052
# 99  Voting does not make sense as a rewardable/pun...          1.562263
#
#     support_origin  predict_origin  gold_origin  undermine_opposite  \
# 0        -0.169901               0            0           -0.638833
# 1        -0.970217               0            0           -2.578271
# 2        -0.680443               0            0           -1.148554
# 3        -0.665140               0            0           -1.294479
# 4        -1.401753               0            0           -1.019519
# ..             ...             ...          ...                 ...
# 95       -0.607702               0            0            2.059047
# 96       -2.150320               0            0            2.330699
# 97       -0.879661               0            0            2.007549
# 98       -0.475252               0            0            2.043130
# 99       -1.498444               0            0           -0.996068
#
#     support_opposite  predict_opposite  gold_opposite  oppose_sum  support_sum
# 0           0.565248                 1              0    0.795512    -0.735148
# 1           2.718875                 1              0    3.598828    -3.689092
# 2           1.108218                 1              0    1.880714    -1.788661
# 3           1.191753                 1              0    2.029992    -1.856893
# 4           0.849479                 1              0    2.468123    -2.251232
# ..               ...               ...            ...         ...          ...
# 95         -1.623067                 0              0   -1.382609     1.015364
# 96         -2.192789                 0              0   -0.179423     0.042469
# 97         -1.668845                 0              0   -0.963966     0.789184
# 98         -1.788328                 0              0   -1.495078     1.313076
# 99          1.227736                 1              0    2.558332    -2.726180
#
# [100 rows x 12 columns]

# %%
integration.loc[integration['oppose_sum']==integration['support_sum'], 'final_label'] = 0
integration.loc[integration['oppose_sum']>integration['support_sum'], 'final_label'] = 0
integration.loc[integration['oppose_sum']<integration['support_sum'], 'final_label'] = 1

# %%
integration
# Out:
#                                    claims  \
# 0                         Golf is a Sport
# 1                         Golf is a Sport
# 2                         Golf is a Sport
# 3                         Golf is a Sport
# 4                         Golf is a Sport
# ..                                    ...
# 95  Voting should be compulsory in the UK
# 96  Voting should be compulsory in the UK
# 97  Voting should be compulsory in the UK
# 98  Voting should be compulsory in the UK
# 99  Voting should be compulsory in the UK
#
#                                           perpectives  undermine_origin  \
# 0   Experts believe golf does not require enough p...          0.156679
# 1   If you can compete in a professional tournamen...          1.020556
# 2   Golf does not have the physical rigors that sp...          0.732160
# 3   The fact that golf can be difficult and requir...          0.735514
# 4   That golf can be difficult and skills and prac...          1.448604
# ..                                                ...               ...
# 95  People can only make free choices if they want...          0.676437
# 96  What's the point of voting as politicians don'...          2.151275
# 97  Why should anyone bother to vote when politici...          1.043582
# 98  Once elected, politicians do what they want, s...          0.548052
# 99  Voting does not make sense as a rewardable/pun...          1.562263
#
#     support_origin  predict_origin  gold_origin  undermine_opposite  \
# 0        -0.169901               0            0           -0.638833
# 1        -0.970217               0            0           -2.578271
# 2        -0.680443               0            0           -1.148554
# 3        -0.665140               0            0           -1.294479
# 4        -1.401753               0            0           -1.019519
# ..             ...             ...          ...                 ...
# 95       -0.607702               0            0            2.059047
# 96       -2.150320               0            0            2.330699
# 97       -0.879661               0            0            2.007549
# 98       -0.475252               0            0            2.043130
# 99       -1.498444               0            0           -0.996068
#
#     support_opposite  predict_opposite  gold_opposite  oppose_sum  \
# 0           0.565248                 1              0    0.795512
# 1           2.718875                 1              0    3.598828
# 2           1.108218                 1              0    1.880714
# 3           1.191753                 1              0    2.029992
# 4           0.849479                 1              0    2.468123
# ..               ...               ...            ...         ...
# 95         -1.623067                 0              0   -1.382609
# 96         -2.192789                 0              0   -0.179423
# 97         -1.668845                 0              0   -0.963966
# 98         -1.788328                 0              0   -1.495078
# 99          1.227736                 1              0    2.558332
#
#     support_sum  final_label
# 0     -0.735148          0.0
# 1     -3.689092          0.0
# 2     -1.788661          0.0
# 3     -1.856893          0.0
# 4     -2.251232          0.0
# ..          ...          ...
# 95     1.015364          1.0
# 96     0.042469          1.0
# 97     0.789184          1.0
# 98     1.313076          1.0
# 99    -2.726180          0.0
#
# [100 rows x 13 columns]

# %%
integration[integration.final_label==0]
# Out:
#                                    claims  \
# 0                         Golf is a Sport
# 1                         Golf is a Sport
# 2                         Golf is a Sport
# 3                         Golf is a Sport
# 4                         Golf is a Sport
# ..                                    ...
# 90  Voting should be compulsory in the UK
# 91  Voting should be compulsory in the UK
# 92  Voting should be compulsory in the UK
# 93  Voting should be compulsory in the UK
# 99  Voting should be compulsory in the UK
#
#                                           perpectives  undermine_origin  \
# 0   Experts believe golf does not require enough p...          0.156679
# 1   If you can compete in a professional tournamen...          1.020556
# 2   Golf does not have the physical rigors that sp...          0.732160
# 3   The fact that golf can be difficult and requir...          0.735514
# 4   That golf can be difficult and skills and prac...          1.448604
# ..                                                ...               ...
# 90  People forced to vote are unlikely to vote int...          0.321807
# 91  If people are forced to vote, they will not ha...          2.716480
# 92                              The right not to vote          0.543965
# 93       Compulsory Voting Does not enhance democracy          0.230329
# 99  Voting does not make sense as a rewardable/pun...          1.562263
#
#     support_origin  predict_origin  gold_origin  undermine_opposite  \
# 0        -0.169901               0            0           -0.638833
# 1        -0.970217               0            0           -2.578271
# 2        -0.680443               0            0           -1.148554
# 3        -0.665140               0            0           -1.294479
# 4        -1.401753               0            0           -1.019519
# ..             ...             ...          ...                 ...
# 90       -0.311967               0            0           -3.393521
# 91       -2.806324               0            0           -3.227855
# 92       -0.506209               0            0           -2.533738
# 93       -0.255880               0            0           -2.520524
# 99       -1.498444               0            0           -0.996068
#
#     support_opposite  predict_opposite  gold_opposite  oppose_sum  \
# 0           0.565248                 1              0    0.795512
# 1           2.718875                 1              0    3.598828
# 2           1.108218                 1              0    1.880714
# 3           1.191753                 1              0    2.029992
# 4           0.849479                 1              0    2.468123
# ..               ...               ...            ...         ...
# 90          3.101883                 1              0    3.715329
# 91          3.023112                 1              0    5.944335
# 92          2.673383                 1              0    3.077704
# 93          2.664057                 1              0    2.750854
# 99          1.227736                 1              0    2.558332
#
#     support_sum  final_label
# 0     -0.735148          0.0
# 1     -3.689092          0.0
# 2     -1.788661          0.0
# 3     -1.856893          0.0
# 4     -2.251232          0.0
# ..          ...          ...
# 90    -3.413851          0.0
# 91    -5.829436          0.0
# 92    -3.179592          0.0
# 93    -2.919937          0.0
# 99    -2.726180          0.0
#
# [84 rows x 13 columns]

# %%
label_list = ["supports", "refutes"]

# %%
label_map = {label : i for i, label in enumerate(label_list)}

# %%
label_map["supports"]
# Out:
# 0

# %%
import spacy
import pandas as pd

nlp = spacy.load("en_core_web_sm")

train_file = "D:/Jupyter/data/dataset/perspective_stances/train.tsv"

df = pd.read_csv(train_file, sep="\t")

# %%
def count_match(matcher, doc, id, matches):
    print(nlp.vocab.strings[match_id])

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(nlp.vocab, attr="lower")
matcher.add("not", None, nlp("not"), nlp("n't"))
matcher.add("can't", None, nlp("can't"))


matcher_positive = PhraseMatcher(nlp.vocab, attr="ORTH")
matcher_positive.add("type", None, nlp("is a type of"), nlp("are a type of") )
matcher_positive.add("imply", None, nlp("implies") )
matcher_positive.add("same", None, nlp("is the same as "), nlp("are the same as ") )
matcher_positive.add("rephrase", None, nlp(" is a rephrasing of") )
matcher_positive.add("form", None, nlp("is a another form of"))
matcher_positive.add("synonym", None, nlp(" is synonymous with"))
matcher_positive.add("can_be", None, nlp("can be"))


matcher_positive.add("much", None, nlp("much"), nlp("Much"))
matcher_positive.add("little", None, nlp("little"), nlp("Little"))
matcher_positive.add("more", None, nlp("more"), nlp("More"))
matcher_positive.add("less", None, nlp("less"), nlp("Less"))


matcher_positive.add("fore_synonym", None, nlp("are synonyms"), nlp("are synonymous"), nlp("is the same thing"), nlp("are the same thing") )
matcher_positive.add("then", None, nlp("then") )
matcher_positive.add("so", None, nlp("so") )
matcher_positive.add("must_be", None, nlp("must be"))
matcher_positive.add("hasto", None, nlp("has to be"))
matcher_positive.add("is_are", None, nlp("is"), nlp("are"), nlp("Are"), nlp("ARE"))

matcher_positive.add("to", None, nlp("to"))
matcher_positive.add("To", None, nlp("To"))
matcher_positive.add("increase", None, nlp("increase"), nlp("increases"), nlp("Increase"))

matcher_positive.add("should", None, nlp("should"), nlp("Should") )
matcher_positive.add("would", None, nlp("would"), nlp("Would"))
matcher_positive.add("could", None, nlp("could"), nlp("Could"))
matcher_positive.add("may", None, nlp("may"), nlp("May"))
matcher_positive.add("will", None, nlp("will"), nlp("Will"))
matcher_positive.add("can", None, nlp("can"), nlp("Can"))
matcher_positive.add("might", None, nlp("might"), nlp("Might"))
matcher_positive.add("must", None, nlp("must"), nlp("Must"), nlp("MUST"))

matcher_positive.add("encourage", None, nlp("encourage"), nlp("encourages"), nlp("Encourage"), nlp("Encourages"))

matcher_positive.add("n’t", None, nlp("n’t"))
matcher_positive.add("was_were", None, nlp("was"), nlp("were"))
matcher_positive.add("raise", None, nlp("raise"), nlp("raises"), nlp("Raise"), nlp("raising"), nlp("Raising"))
matcher_positive.add("better", None, nlp("better"), nlp("Better"))
matcher_positive.add("benefit", None, nlp("benefit"), nlp("benefits"), nlp("Benefit"), nlp("Benefits"))
matcher_positive.add("lack", None, nlp("lack"), nlp("lacks"), nlp("Lack"), nlp("Lacks"))
matcher_positive.add("nothing", None, nlp("nothing"), nlp("Nothing"))
matcher_positive.add("positive", None, nlp("positive"),nlp("Positive"))
matcher_positive.add("negative", None, nlp("negative"), nlp("Negative"))
matcher_positive.add("have", None, nlp("have"),nlp("Have"))
matcher_positive.add("has", None, nlp("has"), nlp("Has"))
matcher_positive.add("reduce", None, nlp("reduce"), nlp("Reduce"), nlp("reduces"), nlp("Reduces"), nlp("Reduced"), nlp("reduced"))
matcher_positive.add("increase", None, nlp("increase"), nlp("Increase"), nlp("increases"), nlp("Increases"), nlp("increased"), nlp("Increased"))
matcher_positive.add("without", None, nlp("without"), nlp("Without"))
matcher_positive.add("against", None, nlp("against"), nlp("Against"))
matcher_positive.add("need", None, nlp("need"), nlp("Need"), nlp("needs"), nlp("Needs"), nlp("needed"), nlp("Needed"))
matcher_positive.add("needed", None, nlp("needed"), nlp("Needed"))
matcher_positive.add("good", None, nlp("good"), nlp("Good"))
matcher_positive.add("bad", None, nlp("bad"), nlp("Bad"))
matcher_positive.add("support", None, nlp("support"), nlp("Support"), nlp("supports"), nlp("Supports"), nlp("supported"), nlp("Supported"))
matcher_positive.add("hurt_harm_damage", None, nlp("hurt"), nlp("hurts"), nlp("harm"), nlp("harms"), nlp("Hurt"), nlp("Hurts"), nlp("Harm"), nlp("Harms"), nlp("HARM"), nlp("damage"), nlp("damages"), nlp("Damage"), nlp("Damages"))
matcher_positive.add("help", None, nlp("help"), nlp("Help"), nlp("helps"), nlp("Helps"))
matcher_positive.add("protect", None, nlp("protect"), nlp("Protect"), nlp("protects"), nlp("Protects"), nlp("protecting"), nlp("protected"), nlp("Protecting"), nlp("Protected"))
matcher_positive.add("cause", None, nlp("cause"), nlp("Cause"), nlp("causes"), nlp("Causes"))
matcher_positive.add("allow", None, nlp("allow"), nlp("Allow"), nlp("allows"), nlp("Allows"))
matcher_positive.add("everyone", None, nlp("everyone"), nlp("Everyone"))
matcher_positive.add("deserve", None, nlp("deserve"), nlp("Deserve"), nlp("deserves"), nlp("Deserves"), nlp("deserved"), nlp("Deserved"))


opposite = []
count_cant=0
count_not=0
count_type=0
count_imply=0
count_same=0
count_rephrase=0
count_form=0
count_synonym=0
count_canbe=0
count_much=0
count_little=0
count_more=0
count_less=0
count_fore_synonym=0
count_then=0
count_so=0
count_must_be=0
count_has_to=0
count_is_are=0
count_to=0
count_To=0
count_increase=0
count_should=0
count_would=0
count_could=0
count_may=0
count_will=0
count_can=0
count_might=0
count_must=0
count_encourage=0
count_nt=0
count_was_were=0
count_raise=0
count_better=0
count_benefit=0
count_lack=0
count_nothing=0
count_positive=0
count_negative=0
count_have=0
count_has=0
count_reduce=0
count_increase=0
count_without=0
count_against=0
count_need=0
count_needed=0
count_good=0
count_bad=0
count_support=0
count_hurt_harm_damage=0
count_help=0
count_protect=0
count_cause=0
count_allow=0
count_everyone=0
count_deserve=0
count_none=0

for claim in df.claim:
    doc = nlp(claim)
    matches = matcher(doc)
    positive_matches = matcher_positive(doc)
    if matches:
        for match_id, start, end in matches:
            rule_id = nlp.vocab.strings[match_id]
            if rule_id == "can't":
                new_seq = str(doc[0:start-1])+" can "+str(doc[end:])
                opposite.append(new_seq)
                count_cant+=1
                break
            elif rule_id == "not":
                if str(doc[start-1:start]) == "ca":
                    continue
                else:
                    new_seq = str(doc[0:start])+" "+str(doc[end:])
                    opposite.append(new_seq)
                    count_not += 1
                    break
    elif positive_matches:
        for match_id, start, end in positive_matches:
            rule_id = nlp.vocab.strings[match_id]
            if rule_id == "type":
                if doc[start:end][0] == "is":
                    new_seq = str(doc[0:start])+" is not a type of "+str(doc[end:])
                    opposite.append(new_seq)
                    count_type +=1
                    break
                elif doc[start:end][0] == "are":
                    new_seq = str(doc[0:start])+" are not a type of "+str(doc[end:])
                    opposite.append(new_seq)
                    count_type +=1
                    break
            elif rule_id == "imply":
                if doc[start:end][0] == "implies":
                    new_seq = str(doc[0:start])+" does not imply "+str(doc[end:])
                    opposite.append(new_seq)
                    count_imply +=1
                    break
                elif doc[start:end][0] == "imply":
                    new_seq = str(doc[0:start])+" do not imply "+str(doc[end:])
                    opposite.append(new_seq)
                    count_imply +=1
                    break
            elif rule_id == "same":
                if doc[start:end][0] == "is":
                    new_seq = str(doc[0:start])+" is not the same as "+str(doc[end:])
                    opposite.append(new_seq)
                    count_same +=1
                    break
                elif doc[start:end][0] == "are":
                    new_seq = str(doc[0:start])+" are not the same as "+str(doc[end:])
                    opposite.append(new_seq)
                    count_same +=1
                    break
            elif rule_id == "rephrase":
                new_seq = str(doc[0:start])+" is not a rephrasing of "+str(doc[end:])
                opposite.append(new_seq)
                count_rephrase +=1
                break 
            elif rule_id == "form":
                new_seq = str(doc[0:start])+" is a another form of "+str(doc[end:])
                opposite.append(new_seq)
                count_form +=1
                break 
            elif rule_id == "synonym":
                new_seq = str(doc[0:start])+" is not synonymous with "+str(doc[end:])
                opposite.append(new_seq)
                count_synonym +=1
                break 
            elif rule_id == "can_be":
                new_seq = str(doc[0:start])+" can't be "+str(doc[end:])
                opposite.append(new_seq)
                count_canbe +=1
                break 
            elif rule_id == "fore_synonym":
                new_seq = str(doc[0:start])+" are not synonymous"
                opposite.append(new_seq)
                count_fore_synonym +=1
                break 
            elif rule_id == "then":
                new_seq = str(doc[0:start])+" doesn't mean "+str(doc[end:])
                opposite.append(new_seq)
                break 
            elif rule_id == "so":
                new_seq = str(doc[0:start])+" does not mean "+str(doc[end:])
                opposite.append(new_seq)
                count_so +=1
                break 
            elif rule_id == "must_be":
                new_seq = str(doc[0:start])+" needn't be "+str(doc[end:])
                opposite.append(new_seq)
                count_must_be +=1
                break 
            elif rule_id == "hasto":
                new_seq = str(doc[0:start])+" doesn't have to be"+str(doc[end:])
                opposite.append(new_seq)
                count_has_to +=1
                break
            elif rule_id == "much":
                if str(doc[start:end][0]) == "Much":
                    new_seq = str("Little "+str(doc[end:]))
                    opposite.append(new_seq)
                    count_much +=1
                    break
                elif str(doc[start:end][0]) == "much":
                    new_seq = str(doc[0:start])+" little "+str(doc[end:])
                    opposite.append(new_seq)
                    count_much +=1
                    break
            elif rule_id == "little":
                if str(doc[start:end][0]) == "Little":
                    new_seq = str("Much "+str(doc[end:]))
                    opposite.append(new_seq)
                    count_little +=1
                    break
                elif str(doc[start:end][0]) == "little":
                    new_seq = str(doc[0:start])+" much "+str(doc[end:])
                    opposite.append(new_seq)
                    count_little +=1
                    break
            elif rule_id == "more":
                if str(doc[start:end][0]) == "More":
                    new_seq = str("Less "+str(doc[end:]))
                    opposite.append(new_seq)
                    count_more +=1
                    break
                elif str(doc[start:end][0]) == "more":
                    new_seq = str(doc[0:start])+" less "+str(doc[end:])
                    opposite.append(new_seq)
                    count_more +=1
                    break
            elif rule_id == "less":
                if str(doc[start:end][0]) == "Less":
                    new_seq = str("More "+str(doc[end:]))
                    opposite.append(new_seq)
                    count_less +=1
                    break
                elif str(doc[start:end][0]) == "less":
                    new_seq = str(doc[0:start])+" more "+str(doc[end:])
                    opposite.append(new_seq)
                    count_less +=1
                    break
            elif rule_id == "is_are":
                if str(doc[start:end][0]) == "is":
                    new_seq = str(doc[0:start])+" is not "+str(doc[end:])
                    opposite.append(new_seq)
                    count_is_are +=1
                    break
                elif str(doc[start:end][0]) == "are":
                    new_seq = str(doc[0:start])+" are not "+str(doc[end:])
                    opposite.append(new_seq)
                    count_is_are +=1
                    break
                elif str(doc[start:end][0]) == "Are":
                    new_seq = str(doc[0:start])+" are not "+str(doc[end:])
                    opposite.append(new_seq)
                    count_is_are +=1
                    break
                elif str(doc[start:end][0]) == "ARE":
                    new_seq = str(doc[0:start])+" are not "+str(doc[end:])
                    opposite.append(new_seq)
                    count_is_are +=1
                    break
            elif rule_id == "to":
                new_seq = str(doc[0:start])+" not to "+str(doc[end:])
                opposite.append(new_seq)
                count_to +=1
                break
            elif rule_id == "To":
                new_seq = str(doc[0:start])+" Not to "+str(doc[end:])
                opposite.append(new_seq)
                break
            elif rule_id == "increase":
                new_seq = str(doc[0:start])+" decrease "+str(doc[end:])
                opposite.append(new_seq)
                count_increase +=1
                break
            elif rule_id == "should":
                new_seq = str(doc[0:start])+" should not "+str(doc[end:])
                opposite.append(new_seq)
                count_should +=1
                break
            elif rule_id == "would":
                new_seq = str(doc[0:start])+" would not "+str(doc[end:])
                opposite.append(new_seq)
                count_would +=1
                break
            elif rule_id == "could":
                new_seq = str(doc[0:start])+" could not "+str(doc[end:])
                opposite.append(new_seq)
                count_could +=1
                break
            elif rule_id == "may":
                new_seq = str(doc[0:start])+" may not "+str(doc[end:])
                opposite.append(new_seq)
                count_may +=1
                break
            elif rule_id == "will":
                new_seq = str(doc[0:start])+" will not "+str(doc[end:])
                opposite.append(new_seq)
                count_will +=1
                break
            elif rule_id == "can":
                new_seq = str(doc[0:start])+" can not "+str(doc[end:])
                opposite.append(new_seq)
                count_can +=1
                break
            elif rule_id == "might":
                new_seq = str(doc[0:start])+" might not "+str(doc[end:])
                opposite.append(new_seq)
                count_might +=1
                break
            elif rule_id == "must":
                new_seq = str(doc[0:start])+" must not "+str(doc[end:])
                opposite.append(new_seq)
                count_must +=1
                break
            elif rule_id == "encourage":
                new_seq = str(doc[0:start])+" discourage "+str(doc[end:])
                opposite.append(new_seq)
                count_encourage +=1
                break
            elif rule_id == "n’t":
                new_seq = str(doc[0:start])+" "+str(doc[end:])
                opposite.append(new_seq)
                count_nt +=1
                break
            elif rule_id == "was_were":
                if str(doc[start:end][0]) == "was":
                    new_seq = str(doc[0:start])+" was not "+str(doc[end:])
                    opposite.append(new_seq)
                    count_was_were +=1
                    break
                elif str(doc[start:end][0]) == "were":
                    new_seq = str(doc[0:start])+" were not "+str(doc[end:])
                    opposite.append(new_seq)
                    count_was_were +=1
                    break
            elif rule_id == "raise":
                new_seq = str(doc[0:start])+" lower "+str(doc[end:])
                opposite.append(new_seq)
                count_raise +=1
                break
            elif rule_id == "better":
                new_seq = str(doc[0:start])+" worse "+str(doc[end:])
                opposite.append(new_seq)
                count_better +=1
                break
            elif rule_id == "benefit":
                new_seq = str(doc[0:start])+" harm "+str(doc[end:])
                opposite.append(new_seq)
                count_benefit +=1
                break
            elif rule_id == "lack":
                new_seq = str(doc[0:start])+" glut "+str(doc[end:])
                opposite.append(new_seq)
                count_lack +=1
                break
            elif rule_id == "nothing":
                new_seq = str(doc[0:start])+" something "+str(doc[end:])
                opposite.append(new_seq)
                count_nothing +=1
                break
            elif rule_id == "positive":
                new_seq = str(doc[0:start])+" negative "+str(doc[end:])
                opposite.append(new_seq)
                count_positive +=1
                break
            elif rule_id == "negative":
                new_seq = str(doc[0:start])+" positive "+str(doc[end:])
                opposite.append(new_seq)
                break
            elif rule_id == "have":
                new_seq = str(doc[0:start])+" don't have "+str(doc[end:])
                opposite.append(new_seq)
                count_have +=1
                break
            elif rule_id == "has":
                new_seq = str(doc[0:start])+" doesn't have "+str(doc[end:])
                opposite.append(new_seq)
                count_has +=1
                break
            elif rule_id == "reduce":
                new_seq = str(doc[0:start])+" increase "+str(doc[end:])
                opposite.append(new_seq)
                count_reduce +=1
                break
            elif rule_id == "increase":
                new_seq = str(doc[0:start])+" decrease "+str(doc[end:])
                opposite.append(new_seq)
                count_increase +=1
                break
            elif rule_id == "without":
                new_seq = str(doc[0:start])+" with "+str(doc[end:])
                opposite.append(new_seq)
                count_without +=1
                break
            elif rule_id == "against":
                new_seq = str(doc[0:start])+" for "+str(doc[end:])
                opposite.append(new_seq)
                count_against +=1
                break
            elif rule_id == "needed":
                new_seq = str(doc[0:start])+" not needed "+str(doc[end:])
                opposite.append(new_seq)
                count_needed +=1
                break
            elif rule_id == "need":
                new_seq = str(doc[0:start])+" don't need "+str(doc[end:])
                opposite.append(new_seq)
                count_need +=1
                break
            elif rule_id == "good":
                new_seq = str(doc[0:start])+" bad "+str(doc[end:])
                opposite.append(new_seq)
                count_good +=1
                break
            elif rule_id == "bad":
                new_seq = str(doc[0:start])+" good "+str(doc[end:])
                opposite.append(new_seq)
                count_bad +=1
                break
            elif rule_id == "support":
                new_seq = str(doc[0:start])+" oppose "+str(doc[end:])
                opposite.append(new_seq)
                count_support +=1
                break
            elif rule_id == "hurt_harm_damage":
                new_seq = str(doc[0:start])+" protect "+str(doc[end:])
                opposite.append(new_seq)
                count_hurt_harm_damage +=1
                break
            elif rule_id == "help":
                new_seq = str(doc[0:start])+" spoil "+str(doc[end:])
                opposite.append(new_seq)
                count_help +=1
                break
            elif rule_id == "protect":
                new_seq = str(doc[0:start])+" destroy "+str(doc[end:])
                opposite.append(new_seq)
                count_protect +=1
                break
            elif rule_id == "cause":
                new_seq = str(doc[0:start])+" casue no "+str(doc[end:])
                opposite.append(new_seq)
                count_cause +=1
                break
            elif rule_id == "allow":
                new_seq = str(doc[0:start])+" disallow "+str(doc[end:])
                opposite.append(new_seq)
                count_allow +=1
                break
            elif rule_id == "everyone":
                new_seq = str(doc[0:start])+" noone "+str(doc[end:])
                opposite.append(new_seq)
                count_everyone +=1
                break
            elif rule_id == "deserve":
                new_seq = str(doc[0:start])+" deserve no "+str(doc[end:])
                opposite.append(new_seq)
                count_deserve +=1
                break
    else:
        new_seq = None
        opposite.append(new_seq)
        count_none +=1
# print(count_cant, count_not)

# print(count_cant,
# count_not,
# count_type,
# count_imply,
# count_same,
# count_rephrase,
# count_form,
# count_synonym,
# count_canbe,
# count_much,
# count_little,
# count_more,
# count_less,
# count_fore_synonym,
# count_then,
# count_so,
# count_must_be,
# count_has_to,
# count_is_are,
# count_to,
# count_To,
# count_increase,
# count_should,
# count_would,
# count_could,
# count_may,
# count_will,
# count_can,
# count_might,
# count_must,
# count_encourage,
# count_nt,
# count_was_were,
# count_raise,
# count_better,
# count_benefit,
# count_lack,
# count_nothing,
# count_positive,
# count_negative,
# count_have,
# count_has,
# count_reduce,
# count_increase,
# count_without,
# count_against,
# count_need,
# count_needed,
# count_good,
# count_bad,
# count_support,
# count_hurt_harm_damage,
# count_help,
# count_protect,
# count_cause,
# count_allow,
# count_everyone,
# count_deserve)
len(opposite)
# Out:
# 7007

# %%
df["opposite_claim"] = opposite
df.dropna()
# Out:
#       Label  x  y                                              claim  \
# 0         0  0  0  Male infant circumcision is tantamount to chil...
# 1         0  0  0  Male infant circumcision is tantamount to chil...
# 2         0  0  0  Male infant circumcision is tantamount to chil...
# 3         1  0  0                 punishment should fit the criminal
# 4         1  0  0                 punishment should fit the criminal
# ...     ... .. ..                                                ...
# 7002      0  0  0                   Internet access is a human right
# 7003      0  0  0                   Internet access is a human right
# 7004      0  0  0                   Internet access is a human right
# 7005      0  0  0                   Internet access is a human right
# 7006      0  0  0                   Internet access is a human right
#
#                                             perspective  \
# 0     Parents have the right to use their best judgm...
# 1               Parents know what best for thier child
# 2     Parents have the right to make the decisions f...
# 3                      It will cause less re-offenders.
# 4          Adequate punishment reduces future offenses.
# ...                                                 ...
# 7002  Piracy is unlikely to be stopped without cutti...
# 7003  These people are breaking the law and need to ...
# 7004                  Criminals deserve to be punished.
# 7005  Illegal downloaders are breaking the law and d...
# 7006  It is a big problem, too many people are file-...
#
#                                          opposite_claim
# 0     Male infant circumcision is not tantamount to ...
# 1     Male infant circumcision is not tantamount to ...
# 2     Male infant circumcision is not tantamount to ...
# 3                punishment should not fit the criminal
# 4                punishment should not fit the criminal
# ...                                                 ...
# 7002               Internet access is not a human right
# 7003               Internet access is not a human right
# 7004               Internet access is not a human right
# 7005               Internet access is not a human right
# 7006               Internet access is not a human right
#
# [6514 rows x 6 columns]

# %%
template_df = pd.DataFrame([count_cant,
count_not,
count_type,
count_imply,
count_same,
count_rephrase,
count_form,
count_synonym,
count_canbe,
count_much,
count_little,
count_more,
count_less,
count_fore_synonym,
count_then,
count_so,
count_must_be,
count_has_to,
count_is_are,
count_to,
count_To,
count_increase,
count_should,
count_would,
count_could,
count_may,
count_will,
count_can,
count_might,
count_must,
count_encourage,
count_nt,
count_was_were,
count_raise,
count_better,
count_benefit,
count_lack,
count_nothing,
count_positive,
count_negative,
count_have,
count_has,
count_reduce,
count_increase,
count_without,
count_against,
count_need,
count_needed,
count_good,
count_bad,
count_support,
count_hurt_harm_damage,
count_help,
count_protect,
count_cause,
count_allow,
count_everyone,
count_deserve],index=["count_cant",
"count_not",
"count_type",
"count_imply",
"count_same",
"count_rephrase",
"count_form",
"count_synonym",
"count_canbe",
"count_much",
"count_little",
"count_more",
"count_less",
"count_fore_synonym",
"count_then",
"count_so",
"count_must_be",
"count_has_to",
"count_is_are",
"count_to",
"count_To",
"count_increase",
"count_should",
"count_would",
"count_could",
"count_may",
"count_will",
"count_can",
"count_might",
"count_must",
"count_encourage",
"count_nt",
"count_was_were",
"count_raise",
"count_better",
"count_benefit",
"count_lack",
"count_nothing",
"count_positive",
"count_negative",
"count_have",
"count_has",
"count_reduce",
"count_increase",
"count_without",
"count_against",
"count_need",
"count_needed",
"count_good",
"count_bad",
"count_support",
"count_hurt_harm_damage",
"count_help",
"count_protect",
"count_cause",
"count_allow",
"count_everyone",
"count_deserve"])
template_df
# Out:
#                            0
# count_cant                23
# count_not                961
# count_type                 0
# count_imply                0
# count_same                 0
# count_rephrase             0
# count_form                 0
# count_synonym              0
# count_canbe                0
# count_much                16
# count_little               4
# count_more               113
# count_less                24
# count_fore_synonym         0
# count_then                 0
# count_so                  10
# count_must_be              0
# count_has_to               0
# count_is_are            1697
# count_to                 513
# count_To                   0
# count_increase            42
# count_should             259
# count_would              469
# count_could               89
# count_may                 62
# count_will               337
# count_can                380
# count_might               13
# count_must                39
# count_encourage           20
# count_nt                  16
# count_was_were            65
# count_raise               32
# count_better              21
# count_benefit             50
# count_lack                20
# count_nothing              9
# count_positive            17
# count_negative             0
# count_have               237
# count_has                202
# count_reduce              30
# count_increase            42
# count_without             22
# count_against             16
# count_need                73
# count_needed               8
# count_good                22
# count_bad                 10
# count_support             26
# count_hurt_harm_damage    49
# count_help                46
# count_protect             29
# count_cause               48
# count_allow               60
# count_everyone            37
# count_deserve             12

# %%
template_df.to_excel("templates_count.xlsx")
