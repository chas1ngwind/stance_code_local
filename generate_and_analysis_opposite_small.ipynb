# %%
import pandas as pd

# %%
df_format=pd.read_csv('D:/Jupyter/stance_code/Dataset/test.tsv',sep ="\t", header=None)
df_small= pd.read_excel('D:/Jupyter/stance_code_local/success_samples/success_500_opposite_gold_0.xlsx')

# %%
df_format
# Out:
#       0  1  2                                                  3  \
# 0     1  0  0                      School Day Should Be Extended
# 1     0  0  0                      School Day Should Be Extended
# 2     1  0  0                      School Day Should Be Extended
# 3     1  0  0                      School Day Should Be Extended
# 4     1  0  0                      School Day Should Be Extended
# ...  .. .. ..                                                ...
# 2768  0  0  0  Illegal downloaders should be cut off from the...
# 2769  0  0  0  Illegal downloaders should be cut off from the...
# 2770  1  0  0  Illegal downloaders should be cut off from the...
# 2771  1  0  0  Illegal downloaders should be cut off from the...
# 2772  1  0  0  Illegal downloaders should be cut off from the...
#
#                                                       4
# 0                       Lessons would feel less broken.
# 1                                  Not enough fundng...
# ...

# %%
df_small
# Out:
#      Unnamed: 0                                             claims  \
# 0            12                 Raise The School Leaving Age To 18
# 1            13                 Raise The School Leaving Age To 18
# 2            15                 Raise The School Leaving Age To 18
# 3            19                 Raise The School Leaving Age To 18
# 4            34                 Raise The School Leaving Age To 18
# ..          ...                                                ...
# 495        1967  An international ban should be placed on the e...
# 496        1976  An international ban should be placed on the e...
# 497        1977  An international ban should be placed on the e...
# 498        1978  An international ban should be placed on the e...
# 499        1980  An international ban should be placed on the e...
#
#                                            perpectives  \
# 0    There are cases where leaving school early is ...
# ...

# %%
df_new = pd.concat([df_format.iloc[0:500],df_small],axis=1)

# %%
df_new
# Out:
#      0  1  2                                           3  \
# 0    1  0  0               School Day Should Be Extended
# 1    0  0  0               School Day Should Be Extended
# 2    1  0  0               School Day Should Be Extended
# 3    1  0  0               School Day Should Be Extended
# 4    1  0  0               School Day Should Be Extended
# ..  .. .. ..                                         ...
# 495  0  0  0  Encourage fewer people to go to university
# 496  0  0  0  Encourage fewer people to go to university
# 497  1  0  0  Encourage fewer people to go to university
# 498  0  0  0  Encourage fewer people to go to university
# 499  0  0  0  Encourage fewer people to go to university
#
#                                                      4  Unnamed: 0  \
# 0                      Lessons would feel less broken.          12
# 1                                 Not enough fundng...          13
# 2                          So much easier for parents!          15
# ...

# %%
col = ["0","1","2", "claims", "opposite", "undermine_score", "support_score"]
final_df = pd.DataFrame(df_new,columns=col)
final_df = final_df.fillna("0")

# %%
final_df
# Out:
#      0  1  2                                             claims  \
# 0    0  0  0                 Raise The School Leaving Age To 18
# 1    0  0  0                 Raise The School Leaving Age To 18
# 2    0  0  0                 Raise The School Leaving Age To 18
# 3    0  0  0                 Raise The School Leaving Age To 18
# 4    0  0  0                 Raise The School Leaving Age To 18
# ..  .. .. ..                                                ...
# 495  0  0  0  An international ban should be placed on the e...
# 496  0  0  0  An international ban should be placed on the e...
# 497  0  0  0  An international ban should be placed on the e...
# 498  0  0  0  An international ban should be placed on the e...
# 499  0  0  0  An international ban should be placed on the e...
#
#                                               opposite  undermine_score  \
# 0    There are no cases where leaving school early ...         0.037721
# ...

# %%
final_df.to_csv("D:/Jupyter/stance_code_local/success_samples/500_gold0/test.tsv",sep="\t",header = None, index=False)

# %%
#after bert prediction

# %%
eval_df = pd.read_csv('D:/Jupyter/stance_code_local/evaluation/bert_local_output/opposite_raw_score.csv')

# %%
eval_df
# Out:
#     undermine_score  support_score  predict_label  gold
# 0         -3.311615       2.915638              1     0
# 1         -2.613755       2.084154              1     0
# 2         -2.250728       1.649728              1     0
# 3          1.656653      -1.931105              0     0
# 4          2.235727      -2.230491              0     0
# ..              ...            ...            ...   ...
# 93         2.344531      -2.364122              0     0
# 94        -0.588766       0.434656              1     0
# 95        -1.058739       0.811802              1     0
# 96        -1.625625       1.306795              1     0
# 97        -0.875861       0.690869              1     0
#
# [98 rows x 4 columns]
