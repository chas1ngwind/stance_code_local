# %%
import pandas as pd

# %%
df_format=pd.read_csv('D:/Jupyter/stance_code/Dataset/test.tsv',sep ="\t", header=None)
df_small= pd.read_excel('D:/Jupyter/stance_code_local/failed_samples/100_opposite_gold_1.xlsx')

# %%
df_format
# Out:
#       0  1  2                                                  3  \
# 0     1  0  0                      School Day Should Be Extended
# 1     0  0  0                      School Day Should Be Extended
# 2     1  0  0                      School Day Should Be Extended
# 3     1  0  0                      School Day Should Be Extended
# 4     1  0  0                      School Day Should Be Extended
# ...  .. .. ..                                                ...
# 2768  0  0  0  Illegal downloaders should be cut off from the...
# 2769  0  0  0  Illegal downloaders should be cut off from the...
# 2770  1  0  0  Illegal downloaders should be cut off from the...
# 2771  1  0  0  Illegal downloaders should be cut off from the...
# 2772  1  0  0  Illegal downloaders should be cut off from the...
#
#                                                       4
# 0                       Lessons would feel less broken.
# 1                                  Not enough fundng...
# 2                           So much easier for parents!
# 3                               Less need for homework.
# 4                             Time to finish activities
# ...                                                 ...
# 2768  Cutting off internet capability is against hum...
# 2769                All humans deserve internet access.
# 2770  Internet access is a commodity not a human right.
# 2771       The internet is a utility not a human right.
# 2772  Just as electricity is not a human right, the ...
#
# [2773 rows x 5 columns]

# %%
df_small
# Out:
#     Unnamed: 0                                             claims  \
# 0           84                   The Catholic Church needs reform
# 1           85                   The Catholic Church needs reform
# 2           88                   The Catholic Church needs reform
# 3           89                   The Catholic Church needs reform
# 4          193                                  Socialism is Dead
# ..         ...                                                ...
# 95        1119  Roger Federer Is Not the Greatest Tennis Playe...
# 96        1130               Aboriginal culture must be protected
# 97        1133               Aboriginal culture must be protected
# 98        1147        Music That Glorifies Crime Should Be Banned
# 99        1164        Music That Glorifies Crime Should Be Banned
#
#                                           perpectives  \
# 0   Currently the Catholic Chuch focuses on loyalt...
# 1   The Catholic Church wants loyalty to instituti...
# 2   If priests were not forced to be celibate, the...
# 3   One of the reasons clerical child rape has hap...
# 4   Globalisation has made socialism impractical t...
# ..                                                ...
# 95     Is not even the best in his current generation
# 96  We cannot understand ourselves if we cannot un...
# 97  In the past we have oppressed native peoples a...
# 98                      violent music harms families
# 99  Music about violence against women  doesn't he...
#
#                                              opposite  undermine_score  \
# 0   Currently the Catholic Chuch focuses on loyalt...         0.497957
# 1   The Catholic Church wants loyalty to the commo...         0.646453
# 2   If priests were forced to be celibate, the iss...         0.461826
# 3   The reason lerical child rape has happened is ...         0.457771
# 4   Globalisation has made socialism practical to ...         0.712595
# ..                                                ...              ...
# 95           He is the best in his current generation         0.411530
# 96  We can understand ourselves even if we cannot ...         1.287267
# 97  In the past we have oppressed native peoples b...         1.127484
# 98                   violent music harms no families          0.568913
# 99  Music about violence against women does help t...         0.037810
#
#     support_score  predict_label  gold_label
# 0       -0.457171              0           1
# 1       -0.561860              0           1
# 2       -0.392891              0           1
# 3       -0.413397              0           1
# 4       -0.677520              0           1
# ..            ...            ...         ...
# 95      -0.364028              0           1
# 96      -1.157720              0           1
# 97      -0.976167              0           1
# 98      -0.404680              0           1
# 99      -0.046061              0           1
#
# [100 rows x 8 columns]

# %%
df_new = pd.concat([df_format.iloc[0:100],df_small],axis=1)

# %%
df_new
# Out:
#     0  1  2                                                  3  \
# 0   1  0  0                      School Day Should Be Extended
# 1   0  0  0                      School Day Should Be Extended
# 2   1  0  0                      School Day Should Be Extended
# 3   1  0  0                      School Day Should Be Extended
# 4   1  0  0                      School Day Should Be Extended
# .. .. .. ..                                                ...
# 95  0  0  0  Positive Discrimination Towards Women in Socie...
# 96  1  0  0  Positive Discrimination Towards Women in Socie...
# 97  1  0  0  Positive Discrimination Towards Women in Socie...
# 98  1  0  0  Positive Discrimination Towards Women in Socie...
# 99  1  0  0  Positive Discrimination Towards Women in Socie...
#
#                                                     4  Unnamed: 0  \
# 0                     Lessons would feel less broken.          84
# 1                                Not enough fundng...          85
# 2                         So much easier for parents!          88
# 3                             Less need for homework.          89
# 4                           Time to finish activities         193
# ..                                                ...         ...
# 95          It does not address the underlying issues        1119
# 96  Positive discrimination towards women should b...        1130
# 97  It is right to treated women differently than ...        1133
# 98  Due to physical difference between men and wom...        1147
# 99  Parliament must be representative of our socie...        1164
#
#                                                claims  \
# 0                    The Catholic Church needs reform
# 1                    The Catholic Church needs reform
# 2                    The Catholic Church needs reform
# 3                    The Catholic Church needs reform
# 4                                   Socialism is Dead
# ..                                                ...
# 95  Roger Federer Is Not the Greatest Tennis Playe...
# 96               Aboriginal culture must be protected
# 97               Aboriginal culture must be protected
# 98        Music That Glorifies Crime Should Be Banned
# 99        Music That Glorifies Crime Should Be Banned
#
#                                           perpectives  \
# 0   Currently the Catholic Chuch focuses on loyalt...
# 1   The Catholic Church wants loyalty to instituti...
# 2   If priests were not forced to be celibate, the...
# 3   One of the reasons clerical child rape has hap...
# 4   Globalisation has made socialism impractical t...
# ..                                                ...
# 95     Is not even the best in his current generation
# 96  We cannot understand ourselves if we cannot un...
# 97  In the past we have oppressed native peoples a...
# 98                      violent music harms families
# 99  Music about violence against women  doesn't he...
#
#                                              opposite  undermine_score  \
# 0   Currently the Catholic Chuch focuses on loyalt...         0.497957
# 1   The Catholic Church wants loyalty to the commo...         0.646453
# 2   If priests were forced to be celibate, the iss...         0.461826
# 3   The reason lerical child rape has happened is ...         0.457771
# 4   Globalisation has made socialism practical to ...         0.712595
# ..                                                ...              ...
# 95           He is the best in his current generation         0.411530
# 96  We can understand ourselves even if we cannot ...         1.287267
# 97  In the past we have oppressed native peoples b...         1.127484
# 98                   violent music harms no families          0.568913
# 99  Music about violence against women does help t...         0.037810
#
#     support_score  predict_label  gold_label
# 0       -0.457171              0           1
# 1       -0.561860              0           1
# 2       -0.392891              0           1
# 3       -0.413397              0           1
# 4       -0.677520              0           1
# ..            ...            ...         ...
# 95      -0.364028              0           1
# 96      -1.157720              0           1
# 97      -0.976167              0           1
# 98      -0.404680              0           1
# 99      -0.046061              0           1
#
# [100 rows x 13 columns]

# %%
col = ["0","1","2", "claims", "opposite", "undermine_score", "support_score"]
final_df = pd.DataFrame(df_new,columns=col)
final_df = final_df.fillna("0")

# %%
final_df
# Out:
#     0  1  2                                             claims  \
# 0   0  0  0                   The Catholic Church needs reform
# 1   0  0  0                   The Catholic Church needs reform
# 2   0  0  0                   The Catholic Church needs reform
# 3   0  0  0                   The Catholic Church needs reform
# 4   0  0  0                                  Socialism is Dead
# .. .. .. ..                                                ...
# 95  0  0  0  Roger Federer Is Not the Greatest Tennis Playe...
# 96  0  0  0               Aboriginal culture must be protected
# 97  0  0  0               Aboriginal culture must be protected
# 98  0  0  0        Music That Glorifies Crime Should Be Banned
# 99  0  0  0        Music That Glorifies Crime Should Be Banned
#
#                                              opposite  undermine_score  \
# 0   Currently the Catholic Chuch focuses on loyalt...         0.497957
# 1   The Catholic Church wants loyalty to the commo...         0.646453
# 2   If priests were forced to be celibate, the iss...         0.461826
# 3   The reason lerical child rape has happened is ...         0.457771
# 4   Globalisation has made socialism practical to ...         0.712595
# ..                                                ...              ...
# 95           He is the best in his current generation         0.411530
# 96  We can understand ourselves even if we cannot ...         1.287267
# 97  In the past we have oppressed native peoples b...         1.127484
# 98                   violent music harms no families          0.568913
# 99  Music about violence against women does help t...         0.037810
#
#     support_score
# 0       -0.457171
# 1       -0.561860
# 2       -0.392891
# 3       -0.413397
# 4       -0.677520
# ..            ...
# 95      -0.364028
# 96      -1.157720
# 97      -0.976167
# 98      -0.404680
# 99      -0.046061
#
# [100 rows x 7 columns]

# %%
final_df.to_csv("D:/Jupyter/stance_code_local/failed_samples/100_gold1/test.tsv",sep="\t",header = None, index=False)

# %%
#after bert prediction

# %%
eval_df = pd.read_csv('D:/Jupyter/stance_code_local/evaluation/bert_local_output/opposite_raw_score.csv')

# %%
eval_df
# Out:
#     undermine_score  support_score  predict_label  gold
# 0         -3.311615       2.915638              1     0
# 1         -2.613755       2.084154              1     0
# 2         -2.250728       1.649728              1     0
# 3          1.656653      -1.931105              0     0
# 4          2.235727      -2.230491              0     0
# ..              ...            ...            ...   ...
# 93         2.344531      -2.364122              0     0
# 94        -0.588766       0.434656              1     0
# 95        -1.058739       0.811802              1     0
# 96        -1.625625       1.306795              1     0
# 97        -0.875861       0.690869              1     0
#
# [98 rows x 4 columns]
